# %%
# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd

# Configuraciones
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
wp1 = pd.read_csv('world-data-2023_part1_limpio.csv', index_col=0)
wp2 = pd.read_csv('world-data-2023_part2.csv', index_col=0)

# %%
wp2.head()
# Out:
#    Unnamed: 0                GDP Gross primary education enrollment (%)  \
# 0           0   $19,101,353,833                                 104.00%
# 1           1   $15,278,077,447                                 107.00%
# 2           2  $169,988,236,398                                 109.90%
# 3           3    $3,154,057,987                                 106.40%
# 4           4   $94,635,415,870                                 113.50%
#
#   Gross tertiary education enrollment (%)  Infant mortality      Largest city  \
# 0                                   9.70%              47.9             Kabul
# 1                                  55.00%               7.8            Tirana
# 2                                  51.40%              20.1           Algiers
# 3                                     NaN               2.7  Andorra la Vella
# 4                                   9.30%              51.6            Luanda
#
# ...

# %%
wp1 = wp1.loc[:, 'Country':]

# %%
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0  Afghanistan               60           AF                58.10%
# 1      Albania              105           AL                43.10%
# 2      Algeria               18           DZ                17.40%
# 3      Andorra              164           AD                40.00%
# 4       Angola               26           AO                47.50%
#
#   Land Area(Km2)  Birth Rate  Calling Code Capital/Major City Co2-Emissions  \
# 0        652,230       32.49          93.0              Kabul         8,672
# 1         28,748       11.78         355.0             Tirana         4,536
# 2      2,381,741       24.28         213.0            Algiers       150,006
# 3            468        7.20         376.0   Andorra la Vella           469
# 4      1,246,700       40.73         244.0             Luanda        34,693
#
#       CPI CPI Change (%) Currency-Code  Fertility Rate Forested Area (%)  \
# ...
