# %% [markdown]
# EJERCICIOS EXPLORATORY DATA ANALYSIS

# %%
# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd

# Configuraciones
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# Ejercicios
#
# 1- Abrid el fichero de rating-and-performance con el método que sea más correcto (este archivo deberias haberlo descargado en el tema anterior).

# %%
df = pd.read_csv("rating-and-performance.csv", index_col=0 )
df.head(3)
# Out:
#                                                                                                                                                                 title  \
# index
# 0                              2020 Summer Vintage Flamingo Print  Pajamas Set Casual Loose T Shirt Top And Elastic Shorts Women Sleepwear Night Wear Loungewear Sets
# 1                                      SSHOUSE Summer Casual Sleeveless Soirée Party Soirée sans manches Vêtements de plage sexy Mini robe femme wshC1612242400387A21
# 2      2020 Nouvelle Arrivée Femmes Printemps et Été Plage Porter Longue Mince Cardigan Ouvert Avant Kimono Vert Feuille Imprimé En Mousseline de Soie Cardigan S-5XL
#
#                                                                                                                                    title_orig  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Set Casual Loose T Shirt Top And Elastic Shorts Women Sleepwear Night Wear Loungewear Sets
# ...

# %% [markdown]
# 2- Mostrad las 10 últimas filas.

# %%
df.tail(10)
# Out:
#                                                                                                                                                  title  \
# index
# 1563                                                              ZANZEA Femmes Été Polka Dot Kaftan Beach Club Party Longue Maxi Dress HOT Long Dress
# 1564          2018 Femme mode d'été en dentelle Patchwork Patchwork Débardeurs Débardeurs Casual Sleeveless Tops Gilet Chemisier (S-5XL) Grande taille
# 1565                                       Nouveau Pantalon De Mode D'été Femmes Leggings Pantalon Déchiré Pantalon Mince Armée Vert Collants Pantalon
# 1566                                                     Robe mi-longue d'été à manches courtes pour femmes Baggy Robes pour femmes Shift Kaftan S-5XL
# 1567                                                    Combinaison sans manches pour femmes couleur unie Dames Slim Short Bodycon Rompers Femmes Body
# ...

# %% [markdown]
# 3- Mostrad 5 filas aleatorias del DataFrame.

# %%
df.sample(5)
# Out:
#                                                                                                                                                                                                           title  \
# index
# 916                                            2020Newest [1200mAh sans fil] Summer Mosquito Bug Zappers Alimentation par batterie Électrique Fly Swatter Bug Zappers Raquette Insectes Killer Home Bug Zappers
# 708                                                                                                     Short Femme Printemps Eté Léopard / Multicolore / Noir / Rouge Short Imprimé Pantalon Court Décontracté
# 1273                                                                                        Nouvelle mode d'été femmes robe décontractée col rond lâche Big Swing jupe sans manches Soild couleur robe de plage
# ...

# %% [markdown]
# 4- ¿Cuántas filas y columnas tenemos en el DataFrame?

# %%
print(df.shape)
print(f"El número de filas es {df.shape[0]} y el de columnas {df.shape[1]}")
# Out:
# (1573, 43)
# El número de filas es 1573 y el de columnas 43

# %% [markdown]
# 5- ¿Cuáles son los nombres de las columnas del DataFrame?

# %%
columnas = df.columns
print(f"Las columnas del dataframe son:\n\n{columnas}")
# Out:
# Las columnas del dataframe son:
#
# Index(['title', 'title_orig', 'price', 'retail_price', 'currency_buyer',
#        'units_sold', 'uses_ad_boosts', 'rating', 'rating_count',
#        'rating_five_count', 'rating_four_count', 'rating_three_count',
#        'rating_two_count', 'rating_one_count', 'badges_count',
#        'badge_local_product', 'badge_product_quality', 'badge_fast_shipping',
#        'tags', 'product_color', 'product_variation_size_id',
#        'product_variation_inventory', 'shipping_option_name',
#        'shipping_option_price', 'shipping_is_express', 'countries_shipped_to',
#        'inventory_total', 'has_urgency_banner', 'urgency_text',
#        'origin_country', 'merchant_title', 'merchant_name',
#        'merchant_info_subtitle', 'merchant_rating_count', 'merchant_rating',
#        'merchant_id', 'merchant_has_profile_picture',
#        'merchant_profile_picture', 'product_url', 'product_picture',
#        'product_id', 'theme', 'crawl_month'],
# ...

# %% [markdown]
# 6- Seleccionad solo las columnas de tipo categórico del DataFrame.

# %%
df_cols_categoricas = df.select_dtypes(include="object")
df_cols_categoricas.head()

# Es más fácil así:

df_cols_categoricas2 = df.select_dtypes(include="object").columns
print(df_cols_categoricas2)
# Out:
# Index(['title', 'title_orig', 'currency_buyer', 'tags', 'product_color',
#        'product_variation_size_id', 'shipping_option_name', 'urgency_text',
#        'origin_country', 'merchant_title', 'merchant_name',
#        'merchant_info_subtitle', 'merchant_id', 'merchant_profile_picture',
#        'product_url', 'product_picture', 'product_id', 'theme', 'crawl_month'],
#       dtype='object')

# %% [markdown]
#  Después, mostrad los valores únicos y sus frecuencias para cada una de las columnas seleccionadas.

# %%
for columna in df_cols_categoricas:
    print("******************")
    print(f"Valores únicos para la columna {columna}:")
    print(df[columna].unique())
    print("--------------------")
    print(f"FRECUENCIAS para los valores de la columna {columna}:")
    print(df[columna].value_counts())
# Out:
# ******************
# Valores únicos para la columna title:
# ['2020 Summer Vintage Flamingo Print  Pajamas Set Casual Loose T Shirt Top And Elastic Shorts Women Sleepwear Night Wear Loungewear Sets'
#  'SSHOUSE Summer Casual Sleeveless Soirée Party Soirée sans manches Vêtements de plage sexy Mini robe femme wshC1612242400387A21'
#  '2020 Nouvelle Arrivée Femmes Printemps et Été Plage Porter Longue Mince Cardigan Ouvert Avant Kimono Vert Feuille Imprimé En Mousseline de Soie Cardigan S-5XL'
#  ...
#  'Nouvelle Mode Femmes Bohême Pissenlit Imprimer Tee Shirt Lady Fille T-shirt À Manches Courtes Boho Graphique Tee Casual Yoga Top Plus La Taille'
#  'Nouveautés Hommes Siwmwear Beach-Shorts Hommes Summer Short de bain court à séchage rapide Beach-Wear Sports'
#  'Pantalon de yoga pour femmes à la mode Slim Fit Fitness Running Leggings']
# --------------------
# FRECUENCIAS para los valores de la columna title:
# title
# ...

# %% [markdown]
# 7- En el DataFrame tenemos dos columnas que parece que nos dan la misma información "title" y "title_orig". Eliminad "title".

# %%
df['title']
# Out:
# index
# 0                               2020 Summer Vintage Flamingo Print  Pajamas Set Casual Loose T Shirt Top And Elastic Shorts Women Sleepwear Night Wear Loungewear Sets
# 1                                       SSHOUSE Summer Casual Sleeveless Soirée Party Soirée sans manches Vêtements de plage sexy Mini robe femme wshC1612242400387A21
# 2       2020 Nouvelle Arrivée Femmes Printemps et Été Plage Porter Longue Mince Cardigan Ouvert Avant Kimono Vert Feuille Imprimé En Mousseline de Soie Cardigan S-5XL
# 3                                 Hot Summer Cool T-shirt pour les femmes Mode Tops Abeille Lettres imprimées Manches courtes O Neck Coton T-shirts Tops Tee Vêtements
# 4                                                                 Femmes Shorts d'été à lacets taille élastique lâche mince pantalon décontracté, plus la taille S-8XL
#                                                                                      ...
# ...

# %%
df['title_orig']
# Out:
# index
# 0       2020 Summer Vintage Flamingo Print  Pajamas Set Casual Loose T Shirt Top And Elastic Shorts Women Sleepwear Night Wear Loungewear Sets
# 1                                                                                             Women's Casual Summer Sleeveless Sexy Mini Dress
# 2           2020 New Arrival Women Spring and Summer Beach Wear Long Thin Cardigan Open Front Kimono Green Leaf Printed Chiffon Cardigan S-5XL
# 3                     Hot Summer Cool T Shirt for Women Fashion Tops Bee Printed Letters Short Sleeve O Neck Cotton T-shirts Tops Tee Clothing
# 4                                                        Women Summer Shorts Lace Up Elastic Waistband Loose Thin Casual Pants Plus Size S-8XL
#                                                                          ...
# 1568             New Fashion Women Bohemia Dandelion Print Tee Shirt Lady Girl Short Sleeve T-shirt Boho Graphic Tee Casual Yoga Top Plus Size
# ...

# %%
df.drop('title', axis=1, inplace=True)
df.head(3)
# Out:
#                                                                                                                                    title_orig  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Set Casual Loose T Shirt Top And Elastic Shorts Women Sleepwear Night Wear Loungewear Sets
# 1                                                                                            Women's Casual Summer Sleeveless Sexy Mini Dress
# 2          2020 New Arrival Women Spring and Summer Beach Wear Long Thin Cardigan Open Front Kimono Green Leaf Printed Chiffon Cardigan S-5XL
#
#        price  retail_price currency_buyer  units_sold  uses_ad_boosts  rating  \
# index
# 0       16.0            14            EUR         100               0    3.76
# 1        8.0            22            EUR       20000               1    3.45
# 2        8.0            43            EUR         100               0    3.57
#
# ...

# %% [markdown]
# 8- ¿En que columnas tenemos valores nulos? Utilizad el método que más os guste.

# %%
df.info()

"""

# Viendo los datos que arroja info, hay valores nulos en las columnas:

 rating_five_count                 1528 non-null   float64
 10  rating_four_count             1528 non-null   float64
 11  rating_three_count            1528 non-null   float64
 12  rating_two_count              1528 non-null   float64
 13  rating_one_count              1528 
 19  product_color                 1532 non-null   object 
 20  product_variation_size_id     1559 non-null   objec
 27  has_urgency_banner            473 non-null    float64
 28  urgency_text                  473 non-null    object 
 29  origin_country
 31  merchant_name                 1569 non-null   object 
 32  merchant_info_subtitle 
 36  merchant_profile_picture     

 """
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1573 entries, 0 to 1572
# Data columns (total 43 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   title                         1573 non-null   object
#  1   title_orig                    1573 non-null   object
#  2   price                         1573 non-null   float64
#  3   retail_price                  1573 non-null   int64
#  4   currency_buyer                1573 non-null   object
#  5   units_sold                    1573 non-null   int64
#  6   uses_ad_boosts                1573 non-null   int64
#  7   rating                        1573 non-null   float64
#  8   rating_count                  1573 non-null   int64
#  9   rating_five_count             1528 non-null   float64
#  10  rating_four_count             1528 non-null   float64
#  11  rating_three_count            1528 non-null   float64
# ...

# %% [markdown]
# 9- ¿Tenemos valores duplicados en el DataFrame?

# %%
df.duplicated().sum()
# Out:
# np.int64(34)

# %%
""" 

Sí, hay valores 34 valores duplicados. Algunos ejemplos son: 

311      True

411      True

447      True

505      True

571      True 

"""
# Out:
# ' \n\nSí, hay valores 34 valores duplicados. Algunos ejemplos son: \n\n311      True\n\n411      True\n\n447      True\n\n505      True\n\n571      True \n\n'
